# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

base_dir = Path.cwd().parent
data_dir = base_dir / "data"

def data_path(filename):
    return data_dir / filename

# %%
df = pd.read_excel(data_path("Online Retail.xlsx"))
df.head(2)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# # DATA PROFILING

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[us]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  str
# dtypes: datetime64[us](1), float64(2), int64(1), object(3), str(1)
# memory usage: 33.1+ MB

# %% [markdown]
# ## Controllo valori mancanti

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.loc[(df["Description"].isna()) & (df["CustomerID"].isna())]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 622       536414     22139         NaN        56 2010-12-01 11:52:00
# 1970      536545     21134         NaN         1 2010-12-01 14:32:00
# 1971      536546     22145         NaN         1 2010-12-01 14:33:00
# 1972      536547     37509         NaN         1 2010-12-01 14:33:00
# 1987      536549    85226A         NaN         1 2010-12-01 14:34:00
# ...          ...       ...         ...       ...                 ...
# 535322    581199     84581         NaN        -2 2011-12-07 18:26:00
# 535326    581203     23406         NaN        15 2011-12-07 18:31:00
# 535332    581209     21620         NaN         6 2011-12-07 18:35:00
# 536981    581234     72817         NaN        27 2011-12-08 10:33:00
# 538554    581408     85175         NaN        20 2011-12-08 14:06:00
#
#         UnitPrice  CustomerID         Country
# 622           0.0         NaN  United Kingdom
# 1970          0.0         NaN  United Kingdom
# 1971          0.0         NaN  United Kingdom
# 1972          0.0         NaN  United Kingdom
# 1987          0.0         NaN  United Kingdom
# ...           ...         ...             ...
# 535322        0.0         NaN  United Kingdom
# 535326        0.0         NaN  United Kingdom
# 535332        0.0         NaN  United Kingdom
# 536981        0.0         NaN  United Kingdom
# 538554        0.0         NaN  United Kingdom
#
# [1454 rows x 8 columns]

# %% [markdown]
# ## Controllo righe duplicate

# %%
df.duplicated().sum()
# Out:
# np.int64(5268)

# %% [markdown]
# ## Controllo outlier

# %%
df.describe()
# Out:
#             Quantity                 InvoiceDate      UnitPrice     CustomerID
# count  541909.000000                      541909  541909.000000  406829.000000
# mean        9.552250  2011-07-04 13:34:57.156386       4.611114   15287.690570
# min    -80995.000000         2010-12-01 08:26:00  -11062.060000   12346.000000
# 25%         1.000000         2011-03-28 11:34:00       1.250000   13953.000000
# 50%         3.000000         2011-07-19 17:17:00       2.080000   15152.000000
# 75%        10.000000         2011-10-19 11:27:00       4.130000   16791.000000
# max     80995.000000         2011-12-09 12:50:00   38970.000000   18287.000000
# std       218.081158                         NaN      96.759853    1713.600303

# %%
df.sort_values("Quantity", ascending=False).head(10)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 540421    581483     23843          PAPER CRAFT , LITTLE BIRDIE     80995
# 61619     541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 502122    578841     84826       ASSTD DESIGN 3D PAPER STICKERS     12540
# 74614     542504     37413                                  NaN      5568
# 421632    573008     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# 206121    554868     22197                 SMALL POPCORN HOLDER      4300
# 220843    556231    85123A                                    ?      4000
# 97432     544612     22053                EMPIRE DESIGN ROSETTE      3906
# 270885    560599     18007  ESSENTIAL BALM 3.5g TIN IN ENVELOPE      3186
# 160546    550461     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 540421 2011-12-09 09:15:00       2.08     16446.0  United Kingdom
# 61619  2011-01-18 10:01:00       1.04     12346.0  United Kingdom
# 502122 2011-11-25 15:57:00       0.00     13256.0  United Kingdom
# 74614  2011-01-28 12:03:00       0.00         NaN  United Kingdom
# 421632 2011-10-27 12:26:00       0.21     12901.0  United Kingdom
# 206121 2011-05-27 10:52:00       0.72     13135.0  United Kingdom
# 220843 2011-06-09 15:04:00       0.00         NaN  United Kingdom
# 97432  2011-02-22 10:43:00       0.82     18087.0  United Kingdom
# 270885 2011-07-19 17:04:00       0.06     14609.0  United Kingdom
# 160546 2011-04-18 13:20:00       2.10     15749.0  United Kingdom

# %%
df.sort_values("UnitPrice", ascending=False).head(20)
# Out:
#        InvoiceNo  StockCode      Description  Quantity         InvoiceDate  \
# 222681   C556445          M           Manual        -1 2011-06-10 15:31:00
# 524602   C580605  AMAZONFEE       AMAZON FEE        -1 2011-12-05 11:36:00
# 43702    C540117  AMAZONFEE       AMAZON FEE        -1 2011-01-05 09:55:00
# 43703    C540118  AMAZONFEE       AMAZON FEE        -1 2011-01-05 09:57:00
# 16356    C537651  AMAZONFEE       AMAZON FEE        -1 2010-12-07 15:49:00
# 15016    C537630  AMAZONFEE       AMAZON FEE        -1 2010-12-07 15:04:00
# 15017     537632  AMAZONFEE       AMAZON FEE         1 2010-12-07 15:08:00
# 16232    C537644  AMAZONFEE       AMAZON FEE        -1 2010-12-07 15:34:00
# 524601   C580604  AMAZONFEE       AMAZON FEE        -1 2011-12-05 11:35:00
# 299982   A563185          B  Adjust bad debt         1 2011-08-12 14:50:00
# 446533   C574902  AMAZONFEE       AMAZON FEE        -1 2011-11-07 15:21:00
# 173277   C551685       POST          POSTAGE        -1 2011-05-03 12:51:00
# 173382    551697       POST          POSTAGE         1 2011-05-03 13:46:00
# 342635   C566899  AMAZONFEE       AMAZON FEE        -1 2011-09-15 13:53:00
# 191386   C553355  AMAZONFEE       AMAZON FEE        -1 2011-05-16 13:58:00
# 173391   C551699          M           Manual        -1 2011-05-03 14:12:00
# 287150   C562086  AMAZONFEE       AMAZON FEE        -1 2011-08-02 12:27:00
# 16357    C537652  AMAZONFEE       AMAZON FEE        -1 2010-12-07 15:51:00
# 312246   C564341  AMAZONFEE       AMAZON FEE        -1 2011-08-24 14:53:00
# 262414   C559917  AMAZONFEE       AMAZON FEE        -1 2011-07-13 15:21:00
#
#         UnitPrice  CustomerID         Country
# 222681   38970.00     15098.0  United Kingdom
# 524602   17836.46         NaN  United Kingdom
# 43702    16888.02         NaN  United Kingdom
# 43703    16453.71         NaN  United Kingdom
# 16356    13541.33         NaN  United Kingdom
# 15016    13541.33         NaN  United Kingdom
# 15017    13541.33         NaN  United Kingdom
# 16232    13474.79         NaN  United Kingdom
# 524601   11586.50         NaN  United Kingdom
# 299982   11062.06         NaN  United Kingdom
# 446533    8286.22         NaN  United Kingdom
# 173277    8142.75     16029.0  United Kingdom
# 173382    8142.75     16029.0  United Kingdom
# 342635    7427.97         NaN  United Kingdom
# 191386    7006.83         NaN  United Kingdom
# 173391    6930.00     16029.0  United Kingdom
# 287150    6721.37         NaN  United Kingdom
# 16357     6706.71         NaN  United Kingdom
# 312246    6662.51         NaN  United Kingdom
# 262414    6497.47         NaN  United Kingdom

# %% [markdown]
# ## Controllo valori negativi

# %%
df.loc[(df["Quantity"] < 0) & (df["InvoiceNo"].str.startswith("C"))]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 141    2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154    2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235    2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236    2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237    2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# ...                    ...        ...         ...             ...
# 540449 2011-12-09 09:57:00       0.83     14397.0  United Kingdom
# 541541 2011-12-09 10:28:00     224.69     15498.0  United Kingdom
# 541715 2011-12-09 11:57:00      10.95     15311.0  United Kingdom
# 541716 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
# 541717 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
#
# [9288 rows x 8 columns]

# %%
df.loc[df["UnitPrice"] < 0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %% [markdown]
# # DATA CLEANING
# Dopo aver creato una copia del df, inizio a fare data cleaning su df_clean dove:
#
# * elimino le righe duplicate
# * sostituisco i valori mancanti in _Description_ con _Missing_ e mantengo inalterati quelli di _CustomerID_
# * escludo i valori con _Quantity_ e _UnitPrice_ negativi, per escludere resi o note di credito che possono falsare le analisi di spesa del cliente
# * mantengo gli outlier, in quanto significativi in sede di EDA

# %% [markdown]
# ## Creo una copia del df

# %%
df_clean = df.copy()

# %% [markdown]
# ## Elimino le righe duplicate

# %%
df_clean.drop_duplicates(inplace=True)

# %% [markdown]
# ## Gestisco i valori mancanti

# %%
df_clean["Description"] = df_clean["Description"].fillna("MISSING")

# %% [markdown]
# ## Escludo i valori negativi

# %%
df_clean = df_clean[(df_clean["Quantity"] >= 0) & (df_clean["UnitPrice"] >= 0)]

# %% [markdown]
# # FEATURE ENGINEERING
# Creo le colonne:
#
# * _Continent_ per condurre indagini sulla distribuzione geografica delle vendite
# * _TotalPrice_ per poter analizzare l'importo di ogni fattura
# * _Year_, _Month_, _Day_ e _DayName_ per valutare l'andamento delle vendite nel tempo.
#
# La colonna _Quantity_ non presenta valori pari a zero, mentre la _UnitPrice_ ne ha 1174, di cui 592 corrispondono ad una _Description_ mancante. Probabilmente, quelli che non hanno _Description_ mancante corrispondono a promozioni o sconti erogati a clienti mentre per i restanti può trattarsi di un errore di registrazione.

# %% [markdown]
# ## Creo la colonna Continent

# %%
continent_segment_map = {
    "Africa": ["RSA"],
    "America": ["Brazil", "Canada", "USA"],
    "Asia": ["Bahrain", "Hong Kong", "Israel", "Japan", "Lebanon", "Saudi Arabia", "Singapore", "United Arab Emirates"],
    "Europe": ["Austria", "Belgium", "Channel Islands", "Cyprus", "Czech Republic", "Denmark", "EIRE", "European Community",
               "Finland", "France", "Germany", "Greece", "Iceland", "Italy", "Lithuania", "Malta", "Netherlands", "Norway", 
               "Poland", "Portugal", "Spain", "Sweden", "Switzerland", "United Kingdom"],
    "Oceania": ["Australia"],
    "Other": ["Unspecified"]
}

# %%
def map_continent_segment(country):
    for segment, country_list in continent_segment_map.items():
        if country in country_list:
            return segment
    return "Other"

# %%
df_clean["Continent"] = df_clean["Country"].apply(map_continent_segment)

# %% [markdown]
# ## Creo la colonna TotalPrice

# %%
df_clean["TotalPrice"] = df_clean["Quantity"] * df_clean["UnitPrice"]

# %% [markdown]
# ## Estraggo le colonne Year, Month, Day and DayName

# %%
df_clean["Year"] = df_clean["InvoiceDate"].dt.year
df_clean["Month"] = df_clean["InvoiceDate"].dt.month
df_clean["Day"] = df_clean["InvoiceDate"].dt.day
df_clean["DayName"] = df_clean["InvoiceDate"].dt.day_name()

# %% [markdown]
# ## Controllo valori di Quantity e UnitPrice pari a 0

# %%
df_clean[df_clean["Quantity"] == 0].shape[0]
# Out:
# 0

# %%
df_clean[df_clean["UnitPrice"] == 0].shape[0]
# Out:
# 1174

# %%
df_clean[(df_clean["UnitPrice"] == 0) & (df_clean["Description"] == "MISSING")].shape[0]
# Out:
# 592

# %% [markdown]
# # EDA

# %% [markdown]
# ## Business Overview
# Dall'analisi preliminare del dataset, questi sono i numeri più importanti:
#
# * 10'642'110 sterline di fatturato prodotto
# * 4339 clienti serviti
# * 20'726 fatture emesse
# * 3941 prodotti venduti

# %% [markdown]
# ### Fatturato totale

# %%
total_revenue = df_clean["TotalPrice"].sum()
total_revenue
# Out:
# np.float64(10642110.804000001)

# %% [markdown]
# ### Numero clienti

# %%
total_customers = df_clean["CustomerID"].nunique()
total_customers
# Out:
# 4339

# %% [markdown]
# ### Numero fatture

# %%
total_invoices = df_clean["InvoiceNo"].nunique()
total_invoices
# Out:
# 20726

# %% [markdown]
# ### Numero prodotti

# %%
total_products = df_clean["StockCode"].nunique()
total_products
# Out:
# 3941

# %% [markdown]
# ## Transaction Analysis
# La distribuzione del fatturato per transazione eseguita risulta fortemente asimmetrica a destra, con la maggior parte delle fatture con importi contenuti. Si evidenzia la presenza di un ristretto numero di fatture che presentano importi superiori a 150 mila sterline per transazione.
#
# Anche il confronto tra fatture emesse e quantità ordinate mostra una distribuzione fortemente right-skewed, in quanto il 75% delle transazioni presenta pochi prodotti fatturati. C'è un ristretto numero di outlier che registrano ordini tra le 75 mila e le 80 mila unità di prodotti per fattura.
#
# Analizzando le quantità di articoli ordinati e i prezzi applicati ad ognuno, viene fuori una distribuzione asimmetricamente positiva, con la maggior parte delle vendite caratterizzate da volumi e prezzi contenuti.

# %% [markdown]
# ### Fatturato per transazione

# %%
invoice_revenue = df_clean.groupby("InvoiceNo")["TotalPrice"].sum()
invoice_revenue.describe()
# Out:
# count     20726.000000
# mean        513.466699
# std        1750.093548
# min           0.000000
# 25%         137.787500
# 50%         297.340000
# 75%         480.355000
# max      168469.600000
# Name: TotalPrice, dtype: float64

# %%
plt.hist(invoice_revenue, log=True)
plt.title("Revenue per Order")
plt.xlabel("Revenue")
plt.ylabel("Orders")
plt.show()

# %% [markdown]
# ### Average Basket Size

# %%
invoice_quantity = df_clean.groupby("InvoiceNo")["Quantity"].sum()
invoice_quantity.describe()
# Out:
# count    20726.000000
# mean       272.364036
# std        944.059110
# min          1.000000
# 25%         63.000000
# 50%        145.000000
# 75%        288.000000
# max      80995.000000
# Name: Quantity, dtype: float64

# %%
plt.hist(invoice_quantity, log=True)
plt.title("Average Basket Size")
plt.xlabel("Quantity")
plt.ylabel("Invoices")
plt.show()

# %% [markdown]
# ### Distribuzione di Quantity e UnitPrice

# %%
df_clean[["Quantity", "UnitPrice"]].describe()
# Out:
#             Quantity      UnitPrice
# count  526052.000000  526052.000000
# mean       10.730911       3.913818
# std       157.592136      36.053205
# min         1.000000       0.000000
# 25%         1.000000       1.250000
# 50%         4.000000       2.080000
# 75%        11.000000       4.130000
# max     80995.000000   13541.330000

# %% [markdown]
# ## Time Analysis
# Dall’analisi del fatturato del 2011 emerge una crescita progressiva delle vendite verso i mesi finali dell’anno, con un picco massimo a novembre, seguito da una flessione nel mese di dicembre.
# Non è possibile effettuare un confronto significativo con il 2010, poiché il dataset contiene dati inerenti al solo mese di dicembre.
#
# Il grafico delle vendite giornalieri mostra una distribuzione regolare nei giorni lavorativi, con attività anche di domenica, seppure con volumi più contenuti. Il sabato, invece, non si registrano vendite.

# %% [markdown]
# ### Vendite per anno e mese

# %%
monthly_revenue = df_clean.groupby(["Year", "Month"]).agg(Revenue=("TotalPrice", "sum"))
monthly_revenue
# Out:
#                 Revenue
# Year Month
# 2010 12      821452.730
# 2011 1       689811.610
#      2       522545.560
#      3       716215.260
#      4       536968.491
#      5       769296.610
#      6       760547.010
#      7       718076.121
#      8       757841.380
#      9      1056435.192
#      10     1151263.730
#      11     1503866.780
#      12      637790.330

# %%
revenue_2010 = monthly_revenue.loc[2010]
revenue_2011 = monthly_revenue.loc[2011]

# %%
plt.scatter(revenue_2010.index, revenue_2010["Revenue"], label=2010, color="red")
plt.plot(revenue_2011.index, revenue_2011["Revenue"], label=2011)
plt.title("Monthly Revenue")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Vendite per giorno della settimana

# %%
dayname_sorted = ["Monday", "Tuesday", "Wednesday",
                 "Thursday", "Friday", "Sunday"]
df_clean["DayName"] = pd.Categorical(df_clean["DayName"], categories=dayname_sorted, ordered=True)

# %%
dayname_revenue = df_clean.groupby("DayName")["TotalPrice"].sum()

# %%
plt.bar(dayname_revenue.index, dayname_revenue)
plt.title("Revenue by Day of Week")
plt.ylabel("Revenue")
plt.grid()
plt.show()

# %% [markdown]
# ### Geographic Analysis
# L'analisi del fatturato per nazione indica che l'attività dell'azienda è concentrata nel proprio paese con un 85% di fatturato prodotto da clienti residenti in Inghilterra. Le sole Australia, Francia, Germania, Irlanda e Paesi Bassi arrivano insieme ad un 10%, mentre il resto delle nazioni si spartisce il restante 5%. Questa predominanza del mercato locale si riflette anche nell'analisi continentale, dove il 98% del fatturato viene prodotto in Europa: al secondo posto c'è l'Oceania con un misero 1%.
#
# Anche in termini di numerosità, l'azienda presenta una forte concentrazione nel mercato domestico, con il 90% della clientela che risiede in Inghilterra e la quasi totalità di clientela residente nel continente europeo.
#
# Il confronto tra quota di fatturato e quota di clienti suggerisce che i clienti esteri spendono mediamente di più di quelli inglesi o europei. Il calcolo della spesa media per nazione evidenzia differenze significative tra i paesi. L'Irlanda presenta il valore medio più elevato, seguita da Paesi Bassi, Singapore e Australia. Il Regno Unito si colloca invece in una posizione più bassa nella classifica. A livello continentale, è l'Oceania ha registrare un valore medio della spesa ben al di sopra di quella europea.
#
# Tale evidenza potrebbe rappresentare un potenziale margine di sviluppo nei mercati esteri, da approfondire attraverso analisi di marginalità e sostenibilità operativa.

# %% [markdown]
# ### Fatturato per nazione

# %%
country_revenue = df_clean.groupby("Country")["TotalPrice"].sum().sort_values()
country_revenue / total_revenue
# Out:
# Country
# Saudi Arabia            0.000014
# Bahrain                 0.000071
# Czech Republic          0.000078
# RSA                     0.000094
# Brazil                  0.000107
# European Community      0.000122
# Lithuania               0.000156
# Lebanon                 0.000159
# United Arab Emirates    0.000179
# Malta                   0.000256
# USA                     0.000336
# Canada                  0.000345
# Iceland                 0.000405
# Unspecified             0.000445
# Greece                  0.000447
# Poland                  0.000689
# Israel                  0.000764
# Austria                 0.000958
# Cyprus                  0.001269
# Hong Kong               0.001455
# Italy                   0.001643
# Denmark                 0.001781
# Channel Islands         0.001921
# Singapore               0.002000
# Finland                 0.002119
# Portugal                0.003165
# Norway                  0.003398
# Japan                   0.003516
# Sweden                  0.003605
# Belgium                 0.003871
# Switzerland             0.005362
# Spain                   0.005784
# Australia               0.013010
# France                  0.019698
# Germany                 0.021488
# EIRE                    0.026606
# Netherlands             0.026822
# United Kingdom          0.845861
# Name: TotalPrice, dtype: float64

# %%
continent_revenue = df_clean.groupby("Continent")["TotalPrice"].sum().sort_values()

# %%
continent_revenue_share = continent_revenue / total_revenue
continent_revenue_share
# Out:
# Continent
# Africa     0.000094
# Other      0.000445
# America    0.000788
# Asia       0.008157
# Oceania    0.013010
# Europe     0.977505
# Name: TotalPrice, dtype: float64

# %%
plt.barh(continent_revenue_share.index, continent_revenue_share)
plt.title("Revenue Share per Continent")
plt.xlabel("Revenue Share")
plt.show()

# %% [markdown]
# ### Clienti per nazione

# %%
country_customers = df_clean.groupby("Country")["CustomerID"].nunique().sort_values()
country_customers / total_customers
# Out:
# Country
# Hong Kong               0.000000
# Brazil                  0.000230
# European Community      0.000230
# Czech Republic          0.000230
# Lebanon                 0.000230
# Lithuania               0.000230
# Iceland                 0.000230
# Singapore               0.000230
# RSA                     0.000230
# Saudi Arabia            0.000230
# Malta                   0.000461
# Bahrain                 0.000461
# United Arab Emirates    0.000461
# EIRE                    0.000691
# Israel                  0.000691
# Canada                  0.000922
# USA                     0.000922
# Unspecified             0.000922
# Greece                  0.000922
# Poland                  0.001383
# Sweden                  0.001844
# Cyprus                  0.001844
# Japan                   0.001844
# Netherlands             0.002074
# Australia               0.002074
# Channel Islands         0.002074
# Denmark                 0.002074
# Norway                  0.002305
# Austria                 0.002535
# Finland                 0.002766
# Italy                   0.003227
# Portugal                0.004379
# Switzerland             0.004840
# Belgium                 0.005762
# Spain                   0.006914
# France                  0.020051
# Germany                 0.021664
# United Kingdom          0.903664
# Name: CustomerID, dtype: float64

# %%
continent_customers = df_clean.groupby("Continent")["CustomerID"].nunique().sort_values()

# %%
continent_customers_share = continent_customers / total_customers
continent_customers_share
# Out:
# Continent
# Africa     0.000230
# Other      0.000922
# Oceania    0.002074
# America    0.002074
# Asia       0.004148
# Europe     0.991012
# Name: CustomerID, dtype: float64

# %%
plt.barh(continent_customers_share.index, continent_customers_share)
plt.title("Customers Share per Continent")
plt.xlabel("Customers Share")
plt.show()

# %% [markdown]
# ### Fatturato medio per nazione

# %%
customers_revenue = df_clean.groupby(["CustomerID", "Country"]).agg(
    TotalPrice=("TotalPrice", "sum"),
    Continent=("Continent", "first")
)

# %%
average_revenue_per_country = customers_revenue.groupby("Country")["TotalPrice"].mean().sort_values()
average_revenue_per_country
# Out:
# Country
# Saudi Arabia              145.920000
# Bahrain                   274.200000
# Unspecified               665.192500
# Czech Republic            826.740000
# USA                       895.097500
# Canada                    916.595000
# Austria                   927.152727
# United Arab Emirates      951.140000
# RSA                      1002.310000
# Brazil                   1143.600000
# Greece                   1190.130000
# Poland                   1222.441667
# Italy                    1248.802857
# European Community       1300.250000
# Malta                    1362.795000
# Belgium                  1647.853600
# Lithuania                1661.060000
# Cyprus                   1687.856250
# Lebanon                  1693.880000
# Portugal                 1756.623158
# United Kingdom           1857.950687
# Finland                  1878.840000
# Spain                    2051.952000
# Denmark                  2106.148889
# Channel Islands          2271.171111
# France                   2401.543793
# Israel                   2405.280000
# Germany                  2432.748936
# Switzerland              2687.807143
# Norway                   3616.544000
# Iceland                  4310.000000
# Japan                    4677.046250
# Sweden                   4795.978750
# Australia               15383.756667
# Singapore               21279.290000
# Netherlands             31716.260000
# EIRE                    88420.820000
# Name: TotalPrice, dtype: float64

# %%
average_revenue_per_continent = customers_revenue.groupby("Continent")["TotalPrice"].mean().sort_values()
average_revenue_per_continent
# Out:
# Continent
# Other        665.192500
# America      932.263333
# Africa      1002.310000
# Europe      2012.656678
# Asia        3900.110000
# Oceania    15383.756667
# Name: TotalPrice, dtype: float64

# %%
plt.barh(average_revenue_per_continent.index, average_revenue_per_continent)
plt.title("Average Revenue per Continent")
plt.xlabel("Average Revenue")
plt.show()

# %% [markdown]
# ## Product Analysis
# Dall'analisi condotta su quantità e fatturato, emerge che i prodotti più venduti in assoluto sono:
#
# - RABBIT NIGHT LIGHT
# - WHITE HANGING HEART T-LIGHT HOLDER
# - JUMBO BAG RED RETROSPOT
# - MEDIUM CERAMIC TOP STORAGE JAR
# - PAPER CRAFT , LITTLE BIRDIE
#
# In particolare, il prodotto PAPER CRAFT, LITTLE BIRDIE è nella top 3 sia per quantità venduta che per fatturato prodotto.
#
# Dall'analisi della top 10 dei prodotti più venduti viene fuori che questi incidono per un 9% circa sulla quantità totale e per un 11% circa sul fatturato globale.

# %%
products = df_clean.groupby(["StockCode", "Description"]).agg(
    Quantity=("Quantity", "sum"),
    TotalPrice=("TotalPrice", "sum")
)

# %% [markdown]
# ### Top 10 prodotti più venduti per quantità

# %%
top10_quantity = products.sort_values("Quantity", ascending=False)\
    .head(10).sort_values("Quantity").reset_index()
top10_quantity
# Out:
#   StockCode                         Description  Quantity  TotalPrice
# 0     22492             MINI PAINT SET VINTAGE      26633    16937.82
# 1     23084                  RABBIT NIGHT LIGHT     30739    66870.03
# 2     84879       ASSORTED COLOUR BIRD ORNAMENT     36362    58927.62
# 3     21212     PACK OF 72 RETROSPOT CAKE CASES     36396    21246.45
# 4     22197                      POPCORN HOLDER     36749    34288.67
# 5    85123A  WHITE HANGING HEART T-LIGHT HOLDER     37584   104284.24
# 6    85099B             JUMBO BAG RED RETROSPOT     48375    94159.81
# 7     84077   WORLD WAR 2 GLIDERS ASSTD DESIGNS     54951    13814.01
# 8     23166      MEDIUM CERAMIC TOP STORAGE JAR     78033    81700.92
# 9     23843         PAPER CRAFT , LITTLE BIRDIE     80995   168469.60

# %%
plt.barh(range(len(top10_quantity)), top10_quantity["Quantity"])
plt.yticks(range(len(top10_quantity)), top10_quantity["Description"])
plt.title("Top 10 Best-Selling Products (by Quantity)")
plt.xlabel("Quantity")
plt.tight_layout()
plt.show()

# %%
top10_quantity_share = (top10_quantity["Quantity"].sum() / products["Quantity"].sum()) * 100
top10_quantity_share
# Out:
# np.float64(8.269541083755815)

# %% [markdown]
# ### Top 10 prodotti più venduti per fatturato

# %%
top10_revenue = products.sort_values("TotalPrice", ascending=False)\
    .head(10).sort_values("TotalPrice").reset_index()
top10_revenue
# Out:
#   StockCode                         Description  Quantity  TotalPrice
# 0     23084                  RABBIT NIGHT LIGHT     30739    66870.03
# 1         M                              Manual      6990    77750.27
# 2      POST                             POSTAGE      3150    78101.88
# 3     23166      MEDIUM CERAMIC TOP STORAGE JAR     78033    81700.92
# 4    85099B             JUMBO BAG RED RETROSPOT     48375    94159.81
# 5     47566                       PARTY BUNTING     18287    99445.23
# 6    85123A  WHITE HANGING HEART T-LIGHT HOLDER     37584   104284.24
# 7     23843         PAPER CRAFT , LITTLE BIRDIE     80995   168469.60
# 8     22423            REGENCY CAKESTAND 3 TIER     13862   174156.54
# 9       DOT                      DOTCOM POSTAGE       708   206248.77

# %%
plt.barh(range(len(top10_revenue)), top10_revenue["TotalPrice"])
plt.yticks(range(len(top10_revenue)), top10_revenue["Description"])
plt.title("Top 10 Best-Selling Products (by Revenue)")
plt.xlabel("Revenue")
plt.tight_layout()
plt.show()

# %%
top10_revenue_share = (top10_revenue["TotalPrice"].sum() / products["TotalPrice"].sum()) * 100
top10_revenue_share
# Out:
# np.float64(10.817283443123976)

# %% [markdown]
# ### Prodotti più venduti in assoluto

# %%
top_products_intersection = pd.merge(top10_quantity, top10_revenue, 
                                     how="inner", on=["StockCode", "Description"])
top_products_intersection[["StockCode", "Description"]]
# Out:
#   StockCode                         Description
# 0     23084                  RABBIT NIGHT LIGHT
# 1    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# 2    85099B             JUMBO BAG RED RETROSPOT
# 3     23166      MEDIUM CERAMIC TOP STORAGE JAR
# 4     23843         PAPER CRAFT , LITTLE BIRDIE

# %% [markdown]
# ## Customer Analysis
# Dall’analisi emerge che il 17% del fatturato totale è generato dai 10 clienti con maggiore spesa, che rappresentano appena lo 0,2% del totale della clientela. Questo dato evidenzia una forte concentrazione del fatturato su un numero estremamente ristretto di clienti, suggerendo una significativa dipendenza dai top spender.
#
# L’analisi della distribuzione della spesa per cliente mostra che la maggior parte dei clienti genera un fatturato contenuto, mentre una piccola quota presenta livelli di spesa molto elevati. Il confronto tra media e mediana (con la media significativamente superiore) conferma la presenza di una distribuzione asimmetrica positiva (right-skewed), tipica di contesti in cui pochi clienti ad alto valore influenzano fortemente il fatturato complessivo.
#
# Il calcolo dell’Average Order Value (AOV) evidenzia come i top 10 clienti presentino un valore medio per ordine superiore alla media globale. Un’eccezione è rappresentata dal cliente 14911, il cui elevato fatturato deriva principalmente da un numero molto alto di ordini piuttosto che da un valore medio per ordine particolarmente elevato.
#
# La Pareto Analysis mostra che circa l’80% del fatturato complessivo è generato dal 26% dei clienti. Questo risultato conferma la presenza di una concentrazione significativa del fatturato su una porzione limitata della clientela, sebbene non perfettamente aderente alla classica regola 80/20.
#
# Infine, è stata costruita una tabella RFM per analizzare il comportamento dei clienti in base a:
# - Recency: giorni trascorsi dall’ultimo acquisto
# - Frequency: numero di ordini effettuati
# - Monetary: totale della spesa
#
# Ad ogni metrica è stato assegnato uno score da 1 a 5, permettendo la costruzione di uno RFM score complessivo e la successiva segmentazione della clientela.
#
# L’analisi evidenzia una presenza significativa di clienti classificati come _Lost_ e _Hibernating_, ovvero clienti inattivi o a basso valore, mentre il segmento _Champion_ rappresenta la fascia di clienti più fedeli e ad alto valore, contribuendo in maniera rilevante al fatturato.

# %%
df_customers = df_clean[df_clean["CustomerID"].notna()].copy()
customers = df_customers.groupby("CustomerID").agg(
    Revenue=("TotalPrice", "sum"),
    Quantity=("Quantity", "sum"),
    Orders=("InvoiceNo", "nunique")
)

# %% [markdown]
# ### Top 10 Spender

# %%
top10_spent_customers = customers["Revenue"].sort_values(ascending=False).head(10)\
    .sort_values(ascending=True)
top10_spent_customers
# Out:
# CustomerID
# 12346.0     77183.60
# 16029.0     80850.84
# 17511.0     91062.38
# 14156.0    117210.08
# 12415.0    124914.53
# 14911.0    143711.17
# 16446.0    168472.50
# 17450.0    194390.79
# 18102.0    259657.30
# 14646.0    280206.02
# Name: Revenue, dtype: float64

# %%
top10_customer_revenue_share = (top10_spent_customers.sum() / customers["Revenue"].sum()) * 100
top10_customer_revenue_share
# Out:
# np.float64(17.301936168487227)

# %%
top10_customers_share = (10 / customers.shape[0]) * 100
top10_customers_share
# Out:
# 0.23046784973496198

# %%
plt.barh(top10_spent_customers.index.astype(str), top10_spent_customers)
plt.title("Top 10 Spender")
plt.xlabel("Revenue")
plt.ylabel("Customers")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Distribuzione della spesa clienti

# %%
customers["Revenue"].describe()
# Out:
# count      4339.000000
# mean       2048.215924
# std        8984.248352
# min           0.000000
# 25%         306.455000
# 50%         668.560000
# 75%        1660.315000
# max      280206.020000
# Name: Revenue, dtype: float64

# %%
plt.hist(customers["Revenue"], log=True)
plt.title("Customer Revenue Distribution")
plt.xlabel("Revenue")
plt.ylabel("Number of Customers")
plt.show()

# %% [markdown]
# ### Average Order Value

# %%
customers["AOV"] = customers["Revenue"] / customers["Orders"]
customers
# Out:
#              Revenue  Quantity  Orders           AOV
# CustomerID
# 12346.0     77183.60     74215       1  77183.600000
# 12347.0      4310.00      2458       7    615.714286
# 12348.0      1797.24      2341       4    449.310000
# 12349.0      1757.55       631       1   1757.550000
# 12350.0       334.40       197       1    334.400000
# ...              ...       ...     ...           ...
# 18280.0       180.60        45       1    180.600000
# 18281.0        80.82        54       1     80.820000
# 18282.0       178.05       103       2     89.025000
# 18283.0      2045.53      1357      16    127.845625
# 18287.0      1837.28      1586       3    612.426667
#
# [4339 rows x 4 columns]

# %%
customers["AOV"].mean()
# Out:
# np.float64(417.5275009295931)

# %%
customers.sort_values(by="Revenue", ascending=False).head(10)
# Out:
#               Revenue  Quantity  Orders           AOV
# CustomerID
# 14646.0     280206.02    197491      74   3786.567838
# 18102.0     259657.30     64124      60   4327.621667
# 17450.0     194390.79     69973      46   4225.886739
# 16446.0     168472.50     80997       2  84236.250000
# 14911.0     143711.17     80490     201    714.980945
# 12415.0     124914.53     77670      21   5948.310952
# 14156.0     117210.08     57768      55   2131.092364
# 17511.0      91062.38     64549      31   2937.496129
# 16029.0      80850.84     40108      63   1283.346667
# 12346.0      77183.60     74215       1  77183.600000

# %% [markdown]
# ### Pareto Analysis

# %%
customers_sorted = customers.sort_values("Revenue", ascending=False)

# %%
customers_sorted["CumRevenuePct"] = (
    customers_sorted["Revenue"].cumsum() /
    customers_sorted["Revenue"].sum() * 100
)

# %%
customers_sorted["CumCustomersPct"] = (
    np.arange(1, len(customers_sorted) + 1) / total_customers * 100
)
customers_sorted
# Out:
#               Revenue  Quantity  Orders           AOV  CumRevenuePct  \
# CustomerID
# 14646.0     280206.02    197491      74   3786.567838       3.152914
# 18102.0     259657.30     64124      60   4327.621667       6.074610
# 17450.0     194390.79     69973      46   4225.886739       8.261920
# 16446.0     168472.50     80997       2  84236.250000      10.157594
# 14911.0     143711.17     80490     201    714.980945      11.774650
# ...               ...       ...     ...           ...            ...
# 17956.0         12.75         1       1     12.750000      99.999810
# 16454.0          6.90         3       2      3.450000      99.999888
# 14792.0          6.20         2       1      6.200000      99.999958
# 16738.0          3.75         3       1      3.750000     100.000000
# 13256.0          0.00     12540       1      0.000000     100.000000
#
#             CumCustomersPct
# CustomerID
# 14646.0            0.023047
# 18102.0            0.046094
# 17450.0            0.069140
# 16446.0            0.092187
# 14911.0            0.115234
# ...                     ...
# 17956.0           99.907813
# 16454.0           99.930860
# 14792.0           99.953906
# 16738.0           99.976953
# 13256.0          100.000000
#
# [4339 rows x 6 columns]

# %%
pct_customers_80_revenue = customers_sorted.loc[
    customers_sorted["CumRevenuePct"] >= 80, "CumCustomersPct"
].iloc[0]
pct_customers_80_revenue
# Out:
# np.float64(26.042867020050704)

# %%
plt.plot(customers_sorted["CumCustomersPct"], customers_sorted["CumRevenuePct"], zorder=2)
plt.scatter(pct_customers_80_revenue, 80, s=100, color="red", zorder=5)
plt.fill_between(customers_sorted["CumCustomersPct"], customers_sorted["CumRevenuePct"], 
                 color="blue", alpha=0.1, zorder=1)
plt.axhline(80, linestyle="--", zorder=3)
plt.axvline(pct_customers_80_revenue, color="red", zorder=4)
plt.text(
    pct_customers_80_revenue + 2, 80 - 7,
    f"{int(pct_customers_80_revenue)}% customers", color="red", zorder=6
)
plt.title("Pareto Analysis")
plt.xlabel("Cumulative Customers (%)")
plt.ylabel("Cumulative Revenue (%)")
plt.show()

# %% [markdown]
# ### RFM Analysis

# %%
last_date = df_clean["InvoiceDate"].max().normalize()
last_date
# Out:
# Timestamp('2011-12-09 00:00:00')

# %%
customers["LastOrderDate"] = df_customers.groupby("CustomerID")["InvoiceDate"].max().dt.normalize()
customers
# Out:
#              Revenue  Quantity  Orders           AOV LastOrderDate
# CustomerID
# 12346.0     77183.60     74215       1  77183.600000    2011-01-18
# 12347.0      4310.00      2458       7    615.714286    2011-12-07
# 12348.0      1797.24      2341       4    449.310000    2011-09-25
# 12349.0      1757.55       631       1   1757.550000    2011-11-21
# 12350.0       334.40       197       1    334.400000    2011-02-02
# ...              ...       ...     ...           ...           ...
# 18280.0       180.60        45       1    180.600000    2011-03-07
# 18281.0        80.82        54       1     80.820000    2011-06-12
# 18282.0       178.05       103       2     89.025000    2011-12-02
# 18283.0      2045.53      1357      16    127.845625    2011-12-06
# 18287.0      1837.28      1586       3    612.426667    2011-10-28
#
# [4339 rows x 5 columns]

# %%
rfm_analysis = customers[["Revenue", "Orders"]].copy()

rfm_analysis.rename(columns={
    "Revenue": "Monetary",
    "Orders": "Frequency"
}, inplace=True)

# %%
rfm_analysis["Recency"] = (
    last_date - customers["LastOrderDate"]
).dt.days

# %%
rfm_analysis = rfm_analysis[["Recency", "Frequency", "Monetary"]]

# %%
rfm_analysis["Frequency"] \
    .value_counts() \
    .sort_index() \
    .rename_axis("Frequency") \
    .reset_index(name="Customers")
# Out:
#     Frequency  Customers
# 0           1       1494
# 1           2        835
# 2           3        508
# 3           4        387
# 4           5        243
# 5           6        172
# 6           7        143
# 7           8         98
# 8           9         68
# 9          10         54
# 10         11         52
# 11         12         45
# 12         13         30
# 13         14         20
# 14         15         28
# 15         16         11
# 16         17         18
# 17         18         14
# 18         19         12
# 19         20         12
# 20         21         11
# 21         22          5
# 22         23          5
# 23         24          3
# 24         25          8
# 25         26          7
# 26         27          3
# 27         28          6
# 28         29          1
# 29         30          4
# 30         31          3
# 31         32          3
# 32         33          2
# 33         34          3
# 34         35          1
# 35         37          3
# 36         38          2
# 37         39          2
# 38         41          1
# 39         44          1
# 40         45          1
# 41         46          1
# 42         47          2
# 43         48          1
# 44         50          1
# 45         51          1
# 46         55          2
# 47         57          1
# 48         60          1
# 49         62          1
# 50         63          1
# 51         74          1
# 52         86          1
# 53         91          1
# 54         93          1
# 55         97          1
# 56        124          1
# 57        201          1
# 58        210          1

# %%
rfm_analysis["Frequency"].describe()
# Out:
# count    4339.000000
# mean        4.271952
# std         7.705493
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         5.000000
# max       210.000000
# Name: Frequency, dtype: float64

# %%
rfm_analysis["R_score"] = pd.qcut(
    rfm_analysis["Recency"], q=5, labels=[5,4,3,2,1], duplicates="drop"
)

bins = [0, 1, 3, 6, 10, rfm_analysis["Frequency"].max()+1]
rfm_analysis["F_score"] = pd.cut(
    rfm_analysis["Frequency"], bins=bins, labels=[1,2,3,4,5], right=True
)

rfm_analysis["M_score"] = pd.qcut(
    rfm_analysis["Monetary"], q=5, labels=[1,2,3,4,5], duplicates="drop"
)

# %%
rfm_analysis["RFM_score"] = (
    rfm_analysis["R_score"].astype(str) +
    rfm_analysis["F_score"].astype(str) + 
    rfm_analysis["M_score"].astype(str)
)
rfm_analysis
# Out:
#             Recency  Frequency  Monetary R_score F_score M_score RFM_score
# CustomerID
# 12346.0         325          1  77183.60       1       1       5       115
# 12347.0           2          7   4310.00       5       4       5       545
# 12348.0          75          4   1797.24       2       3       4       234
# 12349.0          18          1   1757.55       4       1       4       414
# 12350.0         310          1    334.40       1       1       2       112
# ...             ...        ...       ...     ...     ...     ...       ...
# 18280.0         277          1    180.60       1       1       1       111
# 18281.0         180          1     80.82       1       1       1       111
# 18282.0           7          2    178.05       5       2       1       521
# 18283.0           3         16   2045.53       5       5       4       554
# 18287.0          42          3   1837.28       3       2       4       324
#
# [4339 rows x 7 columns]

# %% [markdown]
# ### Customer Segmentation

# %%
customers_segment = pd.read_csv(
    data_path("RFM Customers Segmentation.csv"),
    sep=";",
    dtype={"RFM_score": "str"}
)

# %%
rfm_analysis = pd.merge(
    left=rfm_analysis.reset_index(),
    right=customers_segment, 
    how="inner",
    on="RFM_score"
)

# %%
customers_segmentation = rfm_analysis["Segment"].value_counts().sort_values()
customers_segmentation
# Out:
# Segment
# Cannot lose him       113
# About to sleep        229
# Loyal customer        232
# At risk               307
# Potential loyalist    371
# Promising             380
# New customer          430
# Need attention        458
# Champion              538
# Lost                  564
# Hibernating           717
# Name: count, dtype: int64

# %%
plt.barh(customers_segmentation.index, customers_segmentation)
plt.title("Number of Customers by Segment")
plt.xlabel("Number of Customers")
plt.tight_layout()
plt.show()

# %%
segment_revenue = rfm_analysis.groupby("Segment")["Monetary"].sum().sort_values()
segment_revenue
# Out:
# Segment
# About to sleep          89053.550
# New customer            98934.130
# Lost                   124057.650
# Cannot lose him        209895.410
# Potential loyalist     256372.351
# Hibernating            298732.532
# Promising              572156.650
# At risk                685477.371
# Need attention         789946.420
# Loyal customer         877872.710
# Champion              4884710.120
# Name: Monetary, dtype: float64

# %%
plt.barh(segment_revenue.index, segment_revenue)
plt.title("Revenue by Customer Segment")
plt.xlabel("Revenue")
plt.tight_layout()
plt.show()
